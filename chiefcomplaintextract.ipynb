# %%
import pke
#import pke library 

extractor = pke.unsupervised.TfIdf()
# current extraction method is the "TfIdf" method from pke library. Others include "KPMiner", "YAKE", "TopicRank".

# %%
extractor.load_document(input='../../complaintscommaseparated.txt', language='en')
print('no errors I think :)')
# Out:
# no errors I think :)

# %%
#idk how this part works yt :(
# Select keyphrase candidates
extractor.candidate_selection()

# Weight the candidates
extractor.candidate_weighting()

# Get the top N keyphrases
keyphrases = extractor.get_n_best(n=10)

print(keyphrases)
# Out:
# WARNING:root:LoadFile._df_counts is hard coded to /opt/anaconda3/envs/Mymeuron/lib/python3.12/site-packages/pke/models/df-semeval2010.tsv.gz
# [('txt', 7.1799090900149345)]
