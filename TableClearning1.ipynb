# %%
import pandas as pd

df = pd.read_csv('edstays.csv')

df.head()
# Out:
#    subject_id     hadm_id   stay_id               intime              outtime  \
# 0    10000032  22595853.0  33258284  2180-05-06 19:17:00  2180-05-06 23:30:00
# 1    10000032  22841357.0  38112554  2180-06-26 15:54:00  2180-06-26 21:31:00
# 2    10000032  25742920.0  35968195  2180-08-05 20:58:00  2180-08-06 01:44:00
# 3    10000032  29079034.0  32952584  2180-07-22 16:24:00  2180-07-23 05:54:00
# 4    10000032  29079034.0  39399961  2180-07-23 05:54:00  2180-07-23 14:00:00
#
#   gender   race arrival_transport disposition
# 0      F  WHITE         AMBULANCE    ADMITTED
# 1      F  WHITE         AMBULANCE    ADMITTED
# 2      F  WHITE         AMBULANCE    ADMITTED
# 3      F  WHITE         AMBULANCE        HOME
# 4      F  WHITE         AMBULANCE    ADMITTED

# %%
import pandas as pd

df_pyx = pd.read_csv('pyxis.csv')

df_pyx.head()
# Out:
#    subject_id   stay_id            charttime  med_rn  \
# 0    10000032  32952584  2180-07-22 17:59:00       1
# 1    10000032  32952584  2180-07-22 17:59:00       1
# 2    10000032  35968195  2180-08-05 22:29:00       1
# 3    10000032  35968195  2180-08-05 22:55:00       2
# 4    10000032  35968195  2180-08-05 22:55:00       3
#
#                                name  gsn_rn      gsn
# 0                 Albuterol Inhaler       1   5037.0
# 1                 Albuterol Inhaler       2  28090.0
# 2                          Morphine       1   4080.0
# 3                 Donnatol (Elixir)       1   4773.0
# 4  Aluminum-Magnesium Hydrox.-Simet       1   2701.0

# %%
merged_df = pd.merge(df_pyx, df, on=['subject_id', 'stay_id'], how='inner')

# %%
merged_df.head()
# Out:
#    subject_id   stay_id            charttime  med_rn  \
# 0    10000032  32952584  2180-07-22 17:59:00       1
# 1    10000032  32952584  2180-07-22 17:59:00       1
# 2    10000032  35968195  2180-08-05 22:29:00       1
# 3    10000032  35968195  2180-08-05 22:55:00       2
# 4    10000032  35968195  2180-08-05 22:55:00       3
#
#                                name  gsn_rn      gsn     hadm_id  \
# 0                 Albuterol Inhaler       1   5037.0  29079034.0
# 1                 Albuterol Inhaler       2  28090.0  29079034.0
# 2                          Morphine       1   4080.0  25742920.0
# 3                 Donnatol (Elixir)       1   4773.0  25742920.0
# 4  Aluminum-Magnesium Hydrox.-Simet       1   2701.0  25742920.0
#
#                 intime              outtime gender   race arrival_transport  \
# 0  2180-07-22 16:24:00  2180-07-23 05:54:00      F  WHITE         AMBULANCE
# 1  2180-07-22 16:24:00  2180-07-23 05:54:00      F  WHITE         AMBULANCE
# ...

# %%
merged_df['intime'] = pd.to_datetime(merged_df['intime'])
merged_df['outtime'] = pd.to_datetime(merged_df['outtime'])

# %%
merged_df['duration'] = merged_df['outtime'] - merged_df['intime']

# %%
merged_df.head(100)
# Out:
#     subject_id   stay_id            charttime  med_rn  \
# 0     10000032  32952584  2180-07-22 17:59:00       1
# 1     10000032  32952584  2180-07-22 17:59:00       1
# 2     10000032  35968195  2180-08-05 22:29:00       1
# 3     10000032  35968195  2180-08-05 22:55:00       2
# 4     10000032  35968195  2180-08-05 22:55:00       3
# ..         ...       ...                  ...     ...
# 95    10000980  35392246  2190-11-06 17:33:00       3
# 96    10000980  35392246  2190-11-06 20:39:00       4
# 97    10000980  36549081  2191-05-30 14:03:00       1
# 98    10000980  36549081  2191-05-30 14:03:00       2
# 99    10000980  36549081  2191-05-30 15:26:00       3
#
#                                 name  gsn_rn      gsn     hadm_id  \
# 0                  Albuterol Inhaler       1   5037.0  29079034.0
# 1                  Albuterol Inhaler       2  28090.0  29079034.0
# 2                           Morphine       1   4080.0  25742920.0
# ...

# %%
merged_df.isna().any()
# Out:
# subject_id           False
# stay_id              False
# charttime            False
# med_rn               False
# name                 False
# gsn_rn               False
# gsn                   True
# hadm_id               True
# intime               False
# outtime              False
# gender               False
# race                 False
# arrival_transport    False
# disposition          False
# duration             False
# dtype: bool

# %%
merged_df.dtypes
# Out:
# subject_id                     int64
# stay_id                        int64
# charttime                     object
# med_rn                         int64
# name                          object
# gsn_rn                         int64
# gsn                          float64
# hadm_id                      float64
# intime                datetime64[ns]
# outtime               datetime64[ns]
# gender                        object
# race                          object
# arrival_transport             object
# disposition                   object
# duration             timedelta64[ns]
# dtype: object

# %%
triage = pd.read_csv('triage.csv')
triage.head(100)
# Out:
#     subject_id   stay_id  temperature  heartrate  resprate  o2sat    sbp  \
# 0     10000032  32952584         97.8       87.0      14.0   97.0   71.0
# 1     10000032  33258284         98.4       70.0      16.0   97.0  106.0
# 2     10000032  35968195         99.4      105.0      18.0   96.0  106.0
# 3     10000032  38112554         98.9       88.0      18.0   97.0  116.0
# 4     10000032  39399961         98.7       77.0      16.0   98.0   96.0
# ..         ...       ...          ...        ...       ...    ...    ...
# 95    10002013  34931809         98.4      108.0      16.0   98.0  160.0
# 96    10002013  38018015         97.9       69.0      16.0   96.0  117.0
# 97    10002013  39290684         98.0       88.0      16.0  100.0  127.0
# 98    10002013  39298309         97.5       67.0      16.0  100.0  127.0
# 99    10002013  39407760         98.2      106.0      16.0   99.0  167.0
#
#      dbp pain  acuity                            chiefcomplaint
# ...

# %%
triage_model_train = pd.read_csv('triage.csv')

# %%
X = df.drop(['subject_id', 'stay_id', 'chiefcomplaint', 'acuity'], axis=1)
