# %%
import pandas as pd

edstays_df = pd.read_csv('~/Documents/Mymeuron/mimicdemo/ed/edstays.csv')

edstays_df.head()

#reads in edstays table and displays first 5 rows
# Out:
#    subject_id     hadm_id   stay_id               intime              outtime  \
# 0    10014729  23300884.0  37887480  2125-03-19 12:36:00  2125-03-19 16:59:47
# 1    10018328  26706939.0  34176810  2154-02-05 17:09:00  2154-02-05 22:54:00
# 2    10018328         NaN  32103106  2154-08-03 15:31:00  2154-08-03 22:29:00
# 3    10020640  27984218.0  38797992  2153-02-12 21:59:00  2153-02-13 01:38:00
# 4    10015272  27993466.0  33473053  2137-06-12 16:54:00  2137-06-12 18:37:22
#
#   gender                    race arrival_transport disposition
# 0      F  WHITE - OTHER EUROPEAN           WALK IN    ADMITTED
# 1      F                   WHITE         AMBULANCE    ADMITTED
# 2      F                   WHITE         AMBULANCE        HOME
# 3      F                   WHITE         AMBULANCE    ADMITTED
# 4      F                   WHITE         AMBULANCE    ADMITTED

# %%
import pandas as pd

df_pyx = pd.read_csv('~/Documents/Mymeuron/mimicdemo/ed/pyxis.csv')

df_pyx.head()

#reads in pyxis table and displays first 5 rows
# Out:
#    subject_id   stay_id            charttime  med_rn     name  gsn_rn     gsn
# 0    10012853  36185653  2175-04-05 06:39:00       4  Aspirin       1  4380.0
# 1    10040025  37401157  2145-10-19 23:53:00       2  Aspirin       1  4380.0
# 2    10014354  30279522  2149-09-17 11:51:00       2  Aspirin       1  4380.0
# 3    10040025  30836087  2145-07-04 10:27:00      10  Aspirin       1  4380.0
# 4    10032725  30701739  2143-03-22 21:48:00       2  Aspirin       1  4376.0

# %%
merged_df = pd.merge(df_pyx, edstays_df, on=['subject_id', 'stay_id'], how='inner')

merged_df.head()

#merges pycis and edstays tabes on subject_id and stay_id
# Out:
#    subject_id   stay_id            charttime  med_rn     name  gsn_rn     gsn  \
# 0    10012853  36185653  2175-04-05 06:39:00       4  Aspirin       1  4380.0
# 1    10040025  37401157  2145-10-19 23:53:00       2  Aspirin       1  4380.0
# 2    10014354  30279522  2149-09-17 11:51:00       2  Aspirin       1  4380.0
# 3    10040025  30836087  2145-07-04 10:27:00      10  Aspirin       1  4380.0
# 4    10032725  30701739  2143-03-22 21:48:00       2  Aspirin       1  4376.0
#
#       hadm_id               intime              outtime gender  \
# 0  26369609.0  2175-04-05 06:22:00  2175-04-05 17:10:00      F
# 1  25384176.0  2145-10-19 19:23:00  2145-10-20 00:54:00      F
# 2  26173805.0  2149-09-17 09:08:00  2149-09-17 23:55:00      M
# 3  25172300.0  2145-07-03 20:02:00  2145-07-03 23:46:44      F
# 4  20611640.0  2143-03-22 01:19:00  2143-03-22 06:42:00      F
#
#                      race arrival_transport disposition
# 0  BLACK/AFRICAN AMERICAN         AMBULANCE    ADMITTED
# 1                   WHITE         AMBULANCE    ADMITTED
# 2                   WHITE         AMBULANCE    ADMITTED
# 3                   WHITE           WALK IN    ADMITTED
# 4  BLACK/AFRICAN AMERICAN         AMBULANCE    ADMITTED

# %%
merged_df['intime'] = pd.to_datetime(merged_df['intime'])
merged_df['outtime'] = pd.to_datetime(merged_df['outtime'])

#conversts intime and outtime columns to datetime format

merged_df['duration'] = merged_df['outtime'] - merged_df['intime']

merged_df.head()

# operation to get the duration admitted to ED for each subject/stay
# Out:
#    subject_id   stay_id            charttime  med_rn     name  gsn_rn     gsn  \
# 0    10012853  36185653  2175-04-05 06:39:00       4  Aspirin       1  4380.0
# 1    10040025  37401157  2145-10-19 23:53:00       2  Aspirin       1  4380.0
# 2    10014354  30279522  2149-09-17 11:51:00       2  Aspirin       1  4380.0
# 3    10040025  30836087  2145-07-04 10:27:00      10  Aspirin       1  4380.0
# 4    10032725  30701739  2143-03-22 21:48:00       2  Aspirin       1  4376.0
#
#       hadm_id              intime             outtime gender  \
# 0  26369609.0 2175-04-05 06:22:00 2175-04-05 17:10:00      F
# 1  25384176.0 2145-10-19 19:23:00 2145-10-20 00:54:00      F
# 2  26173805.0 2149-09-17 09:08:00 2149-09-17 23:55:00      M
# 3  25172300.0 2145-07-03 20:02:00 2145-07-03 23:46:44      F
# 4  20611640.0 2143-03-22 01:19:00 2143-03-22 06:42:00      F
#
#                      race arrival_transport disposition        duration
# 0  BLACK/AFRICAN AMERICAN         AMBULANCE    ADMITTED 0 days 10:48:00
# 1                   WHITE         AMBULANCE    ADMITTED 0 days 05:31:00
# 2                   WHITE         AMBULANCE    ADMITTED 0 days 14:47:00
# 3                   WHITE           WALK IN    ADMITTED 0 days 03:44:44
# 4  BLACK/AFRICAN AMERICAN         AMBULANCE    ADMITTED 0 days 05:23:00

# %%
triage_df = pd.read_csv('~/Documents/Mymeuron/mimicdemo/ed/triage.csv')

triage_df.head()

#reads in triage table and displays first 5 rows
# Out:
#    subject_id   stay_id  temperature  heartrate  resprate  o2sat  sbp  dbp  \
# 0    10016742  33211001          NaN        NaN       NaN    NaN  NaN  NaN
# 1    10032725  30701739          NaN        NaN       NaN    NaN  NaN  NaN
# 2    10010867  30115213          NaN        NaN       NaN    NaN  NaN  NaN
# 3    10004235  38926302          NaN        NaN       NaN    NaN  NaN  NaN
# 4    10027602  36678718          NaN        NaN       NaN    NaN  NaN  NaN
#
#   pain  acuity        chiefcomplaint
# 0  NaN     NaN             PICC EVAL
# 1  NaN     NaN          FACIAL DROOP
# 2  NaN     NaN  MVC/INTUBATED TRAUMA
# 3  NaN     NaN            S/P ARREST
# 4  NaN     NaN            HEAD BLEED

# %%
loc_df = pd.merge(merged_df, triage_df, on=['subject_id', 'stay_id'], how='inner')

loc_df.head()

# merges edstays/pyxis dataframe with triage df on subject_id and stay_id
# Out:
#    subject_id   stay_id            charttime  med_rn     name  gsn_rn     gsn  \
# 0    10012853  36185653  2175-04-05 06:39:00       4  Aspirin       1  4380.0
# 1    10040025  37401157  2145-10-19 23:53:00       2  Aspirin       1  4380.0
# 2    10014354  30279522  2149-09-17 11:51:00       2  Aspirin       1  4380.0
# 3    10040025  30836087  2145-07-04 10:27:00      10  Aspirin       1  4380.0
# 4    10032725  30701739  2143-03-22 21:48:00       2  Aspirin       1  4376.0
#
#       hadm_id              intime             outtime  ...        duration  \
# 0  26369609.0 2175-04-05 06:22:00 2175-04-05 17:10:00  ... 0 days 10:48:00
# 1  25384176.0 2145-10-19 19:23:00 2145-10-20 00:54:00  ... 0 days 05:31:00
# 2  26173805.0 2149-09-17 09:08:00 2149-09-17 23:55:00  ... 0 days 14:47:00
# 3  25172300.0 2145-07-03 20:02:00 2145-07-03 23:46:44  ... 0 days 03:44:44
# 4  20611640.0 2143-03-22 01:19:00 2143-03-22 06:42:00  ... 0 days 05:23:00
#
#   temperature heartrate resprate o2sat    sbp   dbp  pain  acuity  \
# 0         NaN       NaN      NaN   NaN    NaN   NaN   NaN     NaN
# 1        98.1      87.0     15.0  92.0  160.0  62.0     0     3.0
# 2        98.2      73.0     20.0  99.0  122.0  60.0     0     3.0
# 3        98.3      77.0     16.0  97.0  197.0  59.0     0     3.0
# 4         NaN       NaN      NaN   NaN    NaN   NaN   NaN     NaN
#
#                chiefcomplaint
# 0                         SOB
# 1      Dyspnea, Foot swelling
# 2                    Weakness
# 3  LEFT EYE SWELLING, REDNESS
# 4                FACIAL DROOP
#
# [5 rows x 24 columns]

# %%
loc_df[[]'subject_id', 'stay_id', 'name', 'gsn', 'duration', 'chiefcomplaint']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/Mymeuron/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('subject_id', 'stay_id', 'name', 'gsn', 'duration', 'chiefcomplaint')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 loc_df['subject_id', 'stay_id', 'name', 'gsn', 'duration', 'chiefcomplaint'].head()
#
# File /opt/anaconda3/envs/Mymeuron/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/anaconda3/envs/Mymeuron/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: ('subject_id', 'stay_id', 'name', 'gsn', 'duration', 'chiefcomplaint')

# %%
loc_df.to_csv('~/Documents/Mymeuron/locdata.csv', index=False)

# %%
merged_df.isna().any()
# Out:
# subject_id           False
# stay_id              False
# charttime            False
# med_rn               False
# name                 False
# gsn_rn               False
# gsn                   True
# hadm_id               True
# intime               False
# outtime              False
# gender               False
# race                 False
# arrival_transport    False
# disposition          False
# duration             False
# dtype: bool

# %%
merged_df.dtypes
# Out:
# subject_id                     int64
# stay_id                        int64
# charttime                     object
# med_rn                         int64
# name                          object
# gsn_rn                         int64
# gsn                          float64
# hadm_id                      float64
# intime                datetime64[ns]
# outtime               datetime64[ns]
# gender                        object
# race                          object
# arrival_transport             object
# disposition                   object
# duration             timedelta64[ns]
# dtype: object

# %%
triage = pd.read_csv('triage.csv')
triage.head(100)

# %%
triage_model_train = pd.read_csv('triage.csv')

# %%
X = df.drop(['subject_id', 'stay_id', 'chiefcomplaint', 'acuity'], axis=1)
